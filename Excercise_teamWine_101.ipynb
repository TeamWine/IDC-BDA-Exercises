# %%
import pandas as pd

# %%
wine_df1 = pd.read_csv ("winemag-data_first150k.csv")
wine_df2 = pd.read_csv ("winemag-data-130k-v2.csv")

# %%
wine_rev = pd.DataFrame()
wine_rev = pd.concat([wine_df1,wine_df2])

# %%
wine_rev.describe()
# Out:
#           Unnamed: 0         points          price
# count  280901.000000  280901.000000  258210.000000
# mean    70615.705960      88.146934      34.177162
# std     41214.379445       3.151528      38.611708
# min         0.000000      80.000000       4.000000
# 25%     35112.000000      86.000000      16.000000
# 50%     70225.000000      88.000000      25.000000
# 75%    105337.000000      90.000000      40.000000
# max    150929.000000     100.000000    3300.000000

# %%
wine_rev.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2 taster_name taster_twitter_handle  \
# 0        Napa Valley               Napa         NaN                   NaN
# 1               Toro                NaN         NaN                   NaN
# 2     Knights Valley             Sonoma         NaN                   NaN
# 3  Willamette Valley  Willamette Valley         NaN                   NaN
# 4             Bandol                NaN         NaN                   NaN
#
#   title             variety                   winery
# 0   NaN  Cabernet Sauvignon                    Heitz
# 1   NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2   NaN     Sauvignon Blanc                 Macauley
# 3   NaN          Pinot Noir                    Ponzi
# 4   NaN  Provence red blend     Domaine de la Bégude

# %%
wine_rev["country"] = pd.Categorical(wine_rev["country"])
wine_rev["province"] = pd.Categorical(wine_rev["province"])
wine_rev["region_1"] = pd.Categorical(wine_rev["region_1"])
wine_rev["region_2"] = pd.Categorical(wine_rev["region_2"])
wine_rev["taster_name"] = pd.Categorical(wine_rev["taster_name"])
wine_rev["variety"] = pd.Categorical(wine_rev["variety"])
wine_rev["winery"] = pd.Categorical(wine_rev["winery"])
wine_rev ["country_code"] = wine_rev["country"].cat.codes
wine_rev ["province_code"] = wine_rev["province"].cat.codes
wine_rev ["region_1_code"] = wine_rev["region_1"].cat.codes
wine_rev ["region_2_code"] = wine_rev["region_2"].cat.codes
wine_rev ["taster_name_code"] = wine_rev["taster_name"].cat.codes
wine_rev ["variety_code"] = wine_rev["variety"].cat.codes
wine_rev ["winery_code"] = wine_rev["winery"].cat.codes
#,"province","region_1","region_2","taster_name","variety","winery"]] = pd.Categorical(wine_rev[["country","province","region_1","region_2","taster_name","variety","winery"]])
#wine_rev[["country_code","province_code","region_1_code","region_2_code","taster_name_code","variety_code","winery_code"]] = wine_rev['country'].,"province","region_1","region_2","taster_name","variety","winery"]]
wine_rev.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2 taster_name     ...      title  \
# 0        Napa Valley               Napa         NaN     ...        NaN
# 1               Toro                NaN         NaN     ...        NaN
# 2     Knights Valley             Sonoma         NaN     ...        NaN
# 3  Willamette Valley  Willamette Valley         NaN     ...        NaN
# 4             Bandol                NaN         NaN     ...        NaN
#
#               variety                   winery country_code  province_code  \
# 0  Cabernet Sauvignon                    Heitz           46             53
# 1       Tinta de Toro  Bodega Carmen Rodríguez           42            296
# 2     Sauvignon Blanc                 Macauley           46             53
# 3          Pinot Noir                    Ponzi           46            305
# 4  Provence red blend     Domaine de la Bégude           16            340
#
#    region_1_code  region_2_code  taster_name_code  variety_code  winery_code
# 0            801              7                -1            84         9617
# 1           1156             -1                -1           655         1596
# 2            576             13                -1           553        11865
# 3           1318             17                -1           476        14377
# 4             71             -1                -1           499         7198
#
# [5 rows x 21 columns]

# %%
wine_rev.describe()
# Out:
#           Unnamed: 0         points          price   country_code  \
# count  280901.000000  280901.000000  258210.000000  280901.000000
# mean    70615.705960      88.146934      34.177162      31.055482
# std     41214.379445       3.151528      38.611708      15.418664
# min         0.000000      80.000000       4.000000      -1.000000
# 25%     35112.000000      86.000000      16.000000      16.000000
# 50%     70225.000000      88.000000      25.000000      35.000000
# 75%    105337.000000      90.000000      40.000000      46.000000
# max    150929.000000     100.000000    3300.000000      49.000000
#
#        province_code  region_1_code  region_2_code  taster_name_code  \
# count  280901.000000  280901.000000  280901.000000     280901.000000
# mean      205.935970     558.060925       2.029007          3.800446
# std       161.132881     441.694724       5.050055          6.820019
# min        -1.000000      -1.000000      -1.000000         -1.000000
# 25%        53.000000     126.000000      -1.000000         -1.000000
# 50%       199.000000     549.000000      -1.000000         -1.000000
# 75%       340.000000     977.000000       3.000000         11.000000
# max       489.000000    1331.000000      17.000000         18.000000
#
#         variety_code    winery_code
# count  280901.000000  280901.000000
# mean      377.341124    9982.731236
# std       214.265527    5546.655191
# min        -1.000000       0.000000
# 25%       132.000000    5597.000000
# 50%       476.000000   10319.000000
# 75%       529.000000   14783.000000
# max       755.000000   19185.000000
